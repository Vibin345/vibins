# %% [markdown]
# Import packages .....

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Load dataset

# %%
data = pd.read_csv('/content/House Price India.csv')

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# Histogram

# %%
sns.histplot(data['lot area'])
# Out:
# <Axes: xlabel='lot area', ylabel='Count'>

# %%
sns.histplot(data['living area'])
# Out:
# <Axes: xlabel='living area', ylabel='Count'>

# %%
sns.histplot(data['number of floors'])
# Out:
# <Axes: xlabel='number of floors', ylabel='Count'>

# %%
sns.histplot(data['Built Year'])
# Out:
# <Axes: xlabel='Built Year', ylabel='Count'>

# %%
sns.histplot(data['Lattitude'])
# Out:
# <Axes: xlabel='Lattitude', ylabel='Count'>

# %%
sns.histplot(data['living_area_renov'])
# Out:
# <Axes: xlabel='living_area_renov', ylabel='Count'>

# %%
sns.histplot(data['condition of the house'])
# Out:
# <Axes: xlabel='condition of the house', ylabel='Count'>

# %%
sns.histplot(data['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='Count'>

# %%
sns.histplot(data['number of bedrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Count'>

# %%
sns.histplot(data['waterfront present'])
# Out:
# <Axes: xlabel='waterfront present', ylabel='Count'>

# %%
sns.histplot(data['number of views'])
# Out:
# <Axes: xlabel='number of views', ylabel='Count'>

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
sns.histplot(data['Longitude'])
# Out:
# <Axes: xlabel='Longitude', ylabel='Count'>

# %%
sns.histplot(data['Number of schools nearby'])
# Out:
# <Axes: xlabel='Number of schools nearby', ylabel='Count'>

# %%
sns.histplot(data['Distance from the airport'])
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='Count'>

# %% [markdown]
# BAR CAHRT

# %%
sns.countplot(data['lot area'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['living area'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['number of floors'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['Built Year'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['Lattitude'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['living_area_renov'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['condition of the house'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['waterfront present'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['number of bedrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['number of bathrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['number of views'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['Longitude'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['Distance from the airport'])
# Out:
# <Axes: ylabel='count'>

# %%
data.hist(figsize=(20,14))
plt.show()

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# PIE CHART

# %%
x = data['number of views'].value_counts()
plt.pie(x.values,
		labels=x.index,
		autopct='%1.1f%%')
plt.show()

# %%
x = data['condition of the house'].value_counts()
plt.pie(x.values,
		labels=x.index,
		autopct='%1.1f%%')
plt.show()

# %%
x = data['Lattitude'].value_counts()
plt.pie(x.values,
		labels=x.index,
		autopct='%1.1f%%')
plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
sns.barplot(x=data['number of bathrooms'], y=data['number of bedrooms'])
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='number of bedrooms'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
sns.barplot(x=data['living area'], y=data['lot area'])
# Out:
# <Axes: xlabel='living area', ylabel='lot area'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
sns.barplot(x=data['number of floors'], y=data['waterfront present'])
# Out:
# <Axes: xlabel='number of floors', ylabel='waterfront present'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
sns.barplot(x=data['Longitude'], y=data['number of bedrooms'])
# Out:
# <Axes: xlabel='Longitude', ylabel='number of bedrooms'>

# %%
sns.scatterplot(x=data['number of bedrooms'],
                y=data['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.scatterplot(x=data['Longitude'],
                y=data['Lattitude'])
# Out:
# <Axes: xlabel='Longitude', ylabel='Lattitude'>

# %%
sns.scatterplot(x=data['number of floors'],
                y=data['waterfront present'])
# Out:
# <Axes: xlabel='number of floors', ylabel='waterfront present'>

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.heatmap(data.corr(), annot=False)
# Out:
# <Axes: >

# %%
sns.pairplot(data=data)
